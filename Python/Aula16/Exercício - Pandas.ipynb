# %% [markdown]
# # <font color='OrangeRed'><center>Exercícios - Pandas</center></font>

# %% [markdown]
# ### Bibliotecas

# %%
# Carregue suas bibliotecas aqui (Opcional)

import pandas

# %% [markdown]
# ### Exercício 01
#
# Carregue o arquivo excel com o nome Vendas.xlxs e em seguida use uma função para exibir o dataframe carregado.

# %%
import pandas

planilha = pandas.read_excel('Vendas.xlsx')

type(planilha)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 02
#
# Use um método para exibir as 10 primeiras linhas do dataframe.

# %%
planilha.head(10)
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário
# 0          Sapato Estampa           1             358
# 1                Camiseta           2             180
# 2           Sapato Xadrez           1             368
# 3                 Relógio           3             200
# 4            Chinelo Liso           1              71
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 03
#
# Use um método para exibir as 5 últimas linhas do dataframe.

# %%
planilha.tail(5)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário
# 93905           2             283
# 93906           2              79
# 93907           3              67
# 93908           5             114
# 93909           4             259

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 04
#
# Use um método para exibir a quantidade de linhas e colunas do dataframe.

# %%
planilha.shape
# Out:
# (93910, 6)

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 05
#
# Exiba apenas as colunas **Produto** e **ID Loja**.

# %%
planilha[['Produto', 'ID Loja' ]]
# Out:
#                  Produto              ID Loja
# 0         Sapato Estampa   Iguatemi Esplanada
# 1               Camiseta   Iguatemi Esplanada
# 2          Sapato Xadrez   Iguatemi Esplanada
# 3                Relógio       Norte Shopping
# 4           Chinelo Liso       Norte Shopping
# ...                  ...                  ...
# 93905     Mochila Xadrez  Shopping Vila Velha
# 93906  Pulseira Listrado    Ribeirão Shopping
# 93907     Cueca Listrado    Ribeirão Shopping
# 93908     Pulseira Linho     Shopping Morumbi
# 93909      Casaco Xadrez     Shopping Morumbi
#
# [93910 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 06
#
# Crie uma coluna chamada **Valor Final** e atribua a ela o valor **Valor Unitário * Quantidade**.

# %%
planilha['Valor Final'] = planilha['Valor Unitário'] * planilha ['Quantidade']

display(planilha)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 07
#
# Crie uma coluna chamada **Comissão** e atribua a ela 5% do valor da coluna **Valor Final**.

# %%
planilha['Comissão'] = planilha['Valor Final'] * 0.05

display(planilha)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão
# 0               1             358          358     17.90
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 08
#
# Filtre as linhas da coluna **ID Loja** onde o valor seja é igual a 'Iguatemi Esplanada' e exiba apenas as colunas **ID Loja**, **Produto** e **Quantidade**.

# %%
planilha.loc[planilha['ID Loja'] == 'Iguatemi Esplanada', ['ID Loja', 'Produto', 'Quantidade']]
# Out:
#                   ID Loja                 Produto  Quantidade
# 0      Iguatemi Esplanada          Sapato Estampa           1
# 1      Iguatemi Esplanada                Camiseta           2
# 2      Iguatemi Esplanada           Sapato Xadrez           1
# 26     Iguatemi Esplanada  Camisa Gola V Listrado           2
# 44     Iguatemi Esplanada         Sapato Listrado           1
# ...                   ...                     ...         ...
# 93745  Iguatemi Esplanada                    Meia           4
# 93776  Iguatemi Esplanada            Tênis Xadrez           3
# 93880  Iguatemi Esplanada            Bermuda Liso           2
# 93881  Iguatemi Esplanada          Chinelo Xadrez           1
# 93882  Iguatemi Esplanada              Cinto Liso           1
#
# [3722 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 09
#
# Filtre as linhas da coluna **ID Loja** onde o valor seja é igual a 'Norte Shopping' e da coluna **Produto** onde o valor seja é igual a 'Camiseta'.

# %%
planilha.loc[ (planilha['ID Loja'] == 'Norte Shopping') & (planilha['Produto'] == 'Camiseta')]
# Out:
#        Código Venda       Data         ID Loja   Produto  Quantidade  \
# 1642           1091 2019-01-07  Norte Shopping  Camiseta           1
# 13899          9523 2019-02-20  Norte Shopping  Camiseta           1
# 15737         10795 2019-02-26  Norte Shopping  Camiseta           1
# 15964         10952 2019-02-27  Norte Shopping  Camiseta           4
# 16068         11039 2019-02-27  Norte Shopping  Camiseta           1
# 16758         11532 2019-03-02  Norte Shopping  Camiseta           1
# 23777         16416 2019-03-27  Norte Shopping  Camiseta           1
# 23855         16472 2019-03-27  Norte Shopping  Camiseta           1
# 24699         17061 2019-03-30  Norte Shopping  Camiseta           1
# 25508         17610 2019-04-02  Norte Shopping  Camiseta           1
# 27281         18808 2019-04-08  Norte Shopping  Camiseta           1
# 29684         20456 2019-04-17  Norte Shopping  Camiseta           2
# 30918         21264 2019-04-21  Norte Shopping  Camiseta           1
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 10
#
# Filtre as linhas da coluna **Produto** onde o valor seja é igual a 'Relógio', 'Gorro' **OU** 'Calça'.

# %%
planilha.loc[ (planilha['Produto'] == 'Relógio') | (planilha['Produto'] == 'Gorro') | (planilha['Produto'] == 'Calça')]
# Out:
#        Código Venda       Data                           ID Loja  Produto  \
# 3                 2 2019-01-02                    Norte Shopping  Relógio
# 6                 5 2019-01-02                    Shopping Barra    Calça
# 46               35 2019-01-02         Parque Dom Pedro Shopping  Relógio
# 50               38 2019-01-02               Shopping Vila Velha  Relógio
# 53               41 2019-01-02      Novo Shopping Ribeirão Preto    Gorro
# ...             ...        ...                               ...      ...
# 93756         64914 2019-11-30                    Norte Shopping    Gorro
# 93778         64929 2019-11-30          Shopping União de Osasco  Relógio
# 93782         64931 2019-11-30  Shopping Center Leste Aricanduva    Gorro
# 93791         64937 2019-11-30         Parque Dom Pedro Shopping  Relógio
# 93823         64957 2019-11-30  Shopping Center Leste Aricanduva    Gorro
#
#        Quantidade  Valor Unitário  Valor Final  Comissão
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 11
#
# Através da coluna **Código Venda**, retorne o número de vendas únicas.

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 12
#
# Imprima o **maior**, o **menor** e a **média** dos valores da coluna **Comissão**

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 13
#
# Agrupe os valores da coluna **ID Loja** e imprima a soma dos valores da coluna **Valor Final**

# %% [markdown]
# ---
